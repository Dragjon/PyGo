# %%
import chess
import chess.polyglot

piece_values_midgame = {
        chess.PAWN: 82,
        chess.KNIGHT: 337,
        chess.BISHOP: 365,
        chess.ROOK: 477,
        chess.QUEEN: 1025,
        chess.KING: 0
    }

piece_values_endgame = {
        chess.PAWN: 94,
        chess.KNIGHT: 281,
        chess.BISHOP: 297,
        chess.ROOK: 512,
        chess.QUEEN: 936,
        chess.KING: 0
    }

piece_square_tables_midgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
-11,  34,  126,  68,  95,  61,  134,  98,
-20,  25,  56,  65,  31,  26,  7,  -6,
-23,  17,  12,  23,  21,  6,  13,  -14,
-25,  10,  6,  17,  12,  -5,  -2,  -27,
-12,  33,  3,  3,  -10,  -4,  -4,  -26,
-22,  38,  24,  -15,  -23,  -20,  -1,  -35,
0,  0,  0,  0,  0,  0,  0,  0
    ],

    chess.KNIGHT:
    [
-107,  -15,  -97,  61,  -49,  -34,  -89,  -167,
-17,  7,  62,  23,  36,  72,  -41,  -73,
44,  73,  129,  84,  65,  37,  60,  -47,
22,  18,  69,  37,  53,  19,  17,  -9,
-8,  21,  19,  28,  13,  16,  4,  -13,
-16,  25,  17,  19,  10,  12,  -9,  -23,
-19,  -14,  18,  -1,  -3,  -12,  -53,  -29,
-23,  -19,  -28,  -17,  -33,  -58,  -21,  -105,
    ],

    chess.BISHOP:
    [
-8,  7,  -42,  -25,  -37,  -82,  4,  -29,
-47,  18,  59,  30,  -13,  -18,  16,  -26,
-2,  37,  50,  35,  40,  43,  37,  -16,
-2,  7,  37,  37,  50,  19,  5,  -4,
4,  10,  12,  34,  26,  13,  13,  -6,
10,  18,  27,  14,  15,  15,  15,  0,
1,  33,  21,  7,  0,  16,  15,  4,
-21,  -39,  -12,  -13,  -21,  -14,  -3,  -33,
    ],

    chess.ROOK:
    [
43,  31,  9,  63,  51,  32,  42,  32,
44,  26,  67,  80,  62,  58,  32,  27,
16,  61,  45,  17,  36,  26,  19,  -5,
-20,  -8,  35,  24,  26,  7,  -11,  -24,
-23,  6,  -7,  9,  -1,  -12,  -26,  -36,
-33,  -5,  0,  3,  -17,  -16,  -25,  -45,
-71,  -6,  11,  -1,  -9,  -20,  -16,  -44,
-26,  -37,  7,  16,  17,  1,  -13,  -19,
    ],

    chess.QUEEN:
    [
45,  43,  44,  59,  12,  29,  0,  -28,
54,  28,  57,  -16,  1,  -5,  -39,  -24,
57,  47,  56,  29,  8,  7,  -17,  -13,
1,  -2,  17,  -1,  -16,  -16,  -27,  -27,
-3,  3,  -4,  -2,  -10,  -9,  -26,  -9,
5,  14,  2,  -5,  -2,  -11,  2,  -14,
1,  -3,  15,  8,  2,  11,  -8,  -35,
-50,  -31,  -25,  -15,  10,  -9,  -18,  -1,
    ],

    chess.KING:
    [
13,  2,  -34,  -56,  -15,  16,  23,  -65,
-29,  -38,  -4,  -8,  -7,  -20,  -1,  29,
-22,  22,  6,  -20,  -16,  2,  24,  -9,
-36,  -14,  -25,  -30,  -27,  -12,  -20,  -17,
-51,  -33,  -44,  -46,  -39,  -27,  -1,  -49,
-27,  -15,  -30,  -44,  -46,  -22,  -14,  -14,
8,  9,  -16,  -43,  -64,  -8,  7,  1,
14,  24,  -28,  -44,  -54,  12,  36,  -15,
    ],

}

piece_square_tables_endgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
187,  165,  132,  147,  134,  158,  173,  178,
84,  82,  53,  56,  67,  85,  100,  94,
17,  17,  4,  -2,  5,  13,  24,  32,
-1,  3,  -8,  -7,  -7,  -3,  9,  13,
-8,  -1,  -5,  0,  1,  -6,  7,  4,
-7,  2,  0,  13,  10,  8,  8,  13,
0,  0,  0,  0,  0,  0,  0,  0,
    ],

    chess.KNIGHT:
    [
-99,  -63,  -27,  -31,  -28,  -13,  -38,  -58,
-52,  -24,  -25,  -9,  -2,  -25,  -8,  -25,
-41,  -19,  -9,  -1,  9,  10,  -20,  -24,
-18,  8,  11,  22,  22,  22,  3,  -17,
-18,  4,  17,  16,  25,  16,  -6,  -18,
-22,  -20,  -3,  10,  15,  -1,  -3,  -23,
-44,  -23,  -20,  -2,  -5,  -10,  -20,  -42,
-64,  -50,  -18,  -22,  -15,  -23,  -51,  -29,
    ],

    chess.BISHOP:
    [
-24,  -17,  -9,  -7,  -8,  -11,  -21,  -14,
-14,  -4,  -13,  -3,  -12,  7,  -4,  -8,
4,  0,  6,  -2,  -1,  0,  -8,  2,
2,  3,  10,  14,  9,  12,  9,  -3,
-9,  -3,  10,  7,  19,  13,  3,  -6,
-15,  -7,  3,  13,  10,  8,  -3,  -12,
-27,  -15,  -9,  4,  -1,  -7,  -18,  -14,
-17,  -5,  -16,  -9,  -5,  -23,  -9,  -23,
    ],

    chess.ROOK:
    [
5,  8,  12,  12,  15,  18,  10,  13,
3,  8,  3,  -3,  11,  13,  13,  11,
-3,  -5,  -3,  4,  5,  7,  7,  7,
2,  -1,  1,  2,  1,  13,  3,  4,
-11,  -8,  -6,  -5,  4,  8,  5,  3,
-16,  -8,  -12,  -7,  -1,  -5,  0,  -4,
-3,  -11,  -9,  -9,  2,  0,  -6,  -6,
-20,  4,  -13,  -5,  -1,  3,  2,  -9,
    ],

    chess.QUEEN:
    [
20,  10,  19,  27,  27,  22,  22,  -9,
0,  30,  25,  58,  41,  32,  20,  -17,
9,  19,  35,  47,  49,  9,  6,  -20,
36,  57,  40,  57,  45,  24,  22,  3,
23,  39,  34,  31,  47,  19,  28,  -18,
5,  10,  17,  9,  6,  15,  -27,  -16,
-32,  -36,  -23,  -16,  -16,  -30,  -23,  -22,
-41,  -20,  -32,  -5,  -43,  -22,  -28,  -33,
    ],

    chess.KING:
    [
-17,  4,  15,  -11,  -18,  -18,  -35,  -74,
11,  23,  38,  17,  17,  14,  17,  -12,
13,  44,  45,  20,  15,  23,  17,  10,
3,  26,  33,  26,  27,  24,  22,  -8,
-11,  9,  23,  27,  24,  21,  -4,  -18,
-9,  7,  16,  23,  21,  11,  -3,  -19,
-17,  -5,  4,  14,  13,  4,  -11,  -27,
-43,  -24,  -14,  -28,  -11,  -21,  -34,  -53,
    ],

}

def evaluate_board(board):
    midgame = not is_endgame(board)

    if midgame:
        piece_values = piece_values_midgame
        piece_square_tables = piece_square_tables_midgame
    else:
        piece_values = piece_values_endgame
        piece_square_tables = piece_square_tables_endgame

    evaluation = 0

    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece is not None:
            sign = 1 if piece.color == chess.WHITE else -1
            piece_type = piece.piece_type

            color = piece.color

            if color == chess.WHITE:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][63 - square]
            else:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][square]

            evaluation += sign * (piece_values[piece_type] + square_value)

    return evaluation


def is_endgame(board):
  # Check if there are no major pieces
  no_major_pieces = (
      sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0)
  if no_major_pieces:
    return True

  # Check for two rooks and no queen
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) <= 1):
    return True

  # Check for two queens or less, kings, and no other pieces except pawns
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0):
    return True

  # If none of the above conditions are met, return False
  return False

def quiescence_search(board, color, alpha, beta, ply):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    stand_pat = color * evaluate_board(board)
    if stand_pat >= beta:
        return beta
    if alpha < stand_pat:
        alpha = stand_pat

    # Sort capture moves using MVV-LVA ordering
    capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
    ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
        board.pop()

        if score >= beta:
            return beta
        if score > alpha:
            alpha = score

    return alpha

def mvv_lva(board, move):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    # Get the piece at the destination square, or None if the square is empty
    to_piece = board.piece_at(move.to_square)

    # Get the piece at the source square, or None if the square is empty
    from_piece = board.piece_at(move.from_square)

    # Calculate MVV-LVA score for a move
    if to_piece is not None and from_piece is not None:
        return piece_values_midgame[to_piece.piece_type] - piece_values_midgame[from_piece.piece_type]
    else:
        # If either square is empty, return a low score
        return -1  # You can adjust this value based on your preferences


def negamax(board, depth, color, alpha, beta, ply):
    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
        
    if depth == 0 or board.is_game_over():
        return quiescence_search(board, color, alpha, beta, ply+1)

    # Sort legal moves using MVV-LVA ordering
    ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        value = -negamax(board, depth - 1, -color, -beta, -alpha, ply+1)
        board.pop()

        alpha = max(alpha, value)
        if alpha >= beta:
            break

    return alpha


def best_move(board, depth):
    if board.turn == chess.WHITE:
        color = 1
    else: 
        color = -1

    alpha = float('-inf')
    beta = float('inf')
    ply = 0

    opening_book_path = 'book/komodo.bin'  # Use the .bin file for polyglot
    # Try moves from the opening book first
    with chess.polyglot.open_reader(opening_book_path) as reader:
        for entry in reader.find_all(board):
            move = entry.move
            if move in board.legal_moves:
                return move  # Return a move from the opening book


    # If no move is found in the opening book, use your existing logic
    ordered_moves = sorted(
        board.legal_moves,
        key=lambda move: (
            -piece_values_midgame[board.piece_at(move.to_square).piece_type]
            if board.piece_at(move.to_square) is not None else 0,
            -piece_values_midgame[board.piece_at(move.from_square).piece_type]
            if board.piece_at(move.from_square) is not None else 0
        )
    )

    best_eval = float('-inf')
    best_mv = None

    for move in ordered_moves:
        board.push(move)
        if board.is_checkmate():
            return move
        eval = -negamax(board, depth - 1, -color, -beta, -alpha, ply+1)
        board.pop()

        if eval > best_eval:
            best_eval = eval
            best_mv = move

        alpha = max(alpha, eval)

    return best_mv

def play_chess():
    board = chess.Board()

    while not board.is_game_over():
        print(board)
        if board.turn == chess.BLACK:
            move = best_move(board, depth=3)
        else:
            move_str = input("Enter your move (in UCI format): ")
            move = chess.Move.from_uci(move_str)

        board.push(move)

    print("Game Over")
    print("Result: ", board.result())

if __name__ == "__main__":
    play_chess()
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 377
#     374     print("Result: ", board.result())
#     376 if __name__ == "__main__":
# --> 377     play_chess()
#
# Cell In[2], line 368, in play_chess()
#     366     move = best_move(board, depth=3)
#     367 else:
# --> 368     move_str = input("Enter your move (in UCI format): ")
#     369     move = chess.Move.from_uci(move_str)
#     371 board.push(move)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import chess

def is_endgame(board):
  # Check if there are no major pieces
  no_major_pieces = (
      sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0)
  if no_major_pieces:
    return True

  # Check for two rooks and no queen
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) <= 1):
    return True

  # Check for two queens or less, kings, and no other pieces except pawns
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0):
    return True

  # If none of the above conditions are met, return False
  return False


# Example usage:
board = chess.Board(fen="8/8/8/3q4/4k3/4P3/4K3/8 w - - 0 1")
print("Is it an endgame?", is_endgame(board))
# Out:
# Is it an endgame? True

# %%
sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK))
# Out:
# 1

# %%
print((sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KING, chess.WHITE)) == 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KING, chess.BLACK)) == 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0))
# Out:
# True

# %%
def reverse_and_print_sections(input_array):
    # Split the input array into 8 sections of 8 squares
    sections = [input_array[i:i + 8] for i in range(0, len(input_array), 8)]

    # Reverse each section
    reversed_sections = [section[::-1] for section in sections]

    # Combine the reversed sections back into a single list
    reversed_array = [square for section in reversed_sections for square in section]

    # Print the reversed array in an 8x8 format
    for i in range(0, len(reversed_array), 8):
        print(',  '.join(map(str, reversed_array[i:i + 8])))

    # Return the reversed 1-dimensional array
    return reversed_array

# Example usage:
input_array = [    -74, -35, -18, -18, -11,  15,   4, -17,
    -12,  17,  14,  17,  17,  38,  23,  11,
     10,  17,  23,  15,  20,  45,  44,  13,
     -8,  22,  24,  27,  26,  33,  26,   3,
    -18,  -4,  21,  24,  27,  23,   9, -11,
    -19,  -3,  11,  21,  23,  16,   7,  -9,
    -27, -11,   4,  13,  14,   4,  -5, -17,
    -53, -34, -21, -11, -28, -14, -24, -43]

output_array = reverse_and_print_sections(input_array)

# %% [markdown]
# # Testing it on checkmates in 2

# %%
def load_test_positions(file_path):
    positions = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' | ')
            fen = parts[0]
            move = parts[1]
            positions.append((fen, move))
    return positions

def test():
    file_path = 'tests/mate-in-2-fens.txt'
    positions = load_test_positions(file_path)

    correct_moves = 0
    total_positions = len(positions)

    for fen, expected_move in positions:
        board = chess.Board(fen)
        best_move_result = best_move(board, depth=3).uci()
        if best_move_result == expected_move:
            correct_moves += 1
        print(f"Position: {fen}\nExpected Move: {expected_move}\nActual Move: {best_move_result}\n")

    accuracy = (correct_moves / total_positions) * 100
    print(f"\nAccuracy: {accuracy:.2f}%")

if __name__ == "__main__":
    test()
# Out:
# Position: 8/4k3/1R3p2/R7/8/8/8/8 w - - 0 1
# Expected Move: a5a7
# Actual Move: a5a7
#
# Position: 8/8/8/8/8/3k4/7q/5K2 b - - 0 1
# Expected Move: d3e3
# Actual Move: d3e3
#
# Position: 1k6/2NB4/1K6/8/8/8/8/8 w - - 0 1
# Expected Move: c7a6
# Actual Move: c7a6
#
# Position: 8/2p1p3/2qbn3/2pkp3/8/1P3K2/6Q1/8 w - - 0 1
# Expected Move: f3e3
# Actual Move: f3e3
#
# Position: 8/5P1k/5K2/8/8/8/8/8 w - - 0 1
# Expected Move: f7f8r
# Actual Move: f7f8r
#
# Position: 8/5n1K/5k2/8/5r2/8/8/8 b - - 0 1
# Expected Move: f4h4
# Actual Move: f4h4
#
# Position: KB6/2rq4/k1p5/8/3p4/8/8/8 b - - 0 1
# Expected Move: c7a7
# Actual Move: c7a7
#
# Position: rnbqkb1r/ppppp2p/5p1n/4N1p1/4P3/8/PPPP1PPP/RNBQKB1R w KQkq - 0 1
# Expected Move: d1h5
# Actual Move: d1h5
#
# Position: kbK5/pp6/1P6/8/8/8/8/R7 w - - 0 1
# Expected Move: a1a6
# Actual Move: a1a6
#
#
# Accuracy: 100.00%

# %% [markdown]
# # Testing it against stockfish moves

# %%
import chess
import chess.engine
import random

def generate_random_move(board, max_depth):
    legal_moves = [move for move in board.legal_moves]
    if not legal_moves:
        return board

    random_move = random.choice(legal_moves)

    depth = random.randint(0, max_depth)

    for _ in range(depth):
        board.push(random_move)
        if board.is_game_over():
            break
        legal_moves = [move for move in board.legal_moves]
        if not legal_moves:
            break
        random_move = random.choice(legal_moves)

    return board

def get_top_moves(stockfish_path, fen):
    with chess.engine.SimpleEngine.popen_uci(stockfish_path) as engine:
        result = engine.analyse(chess.Board(fen), limit=chess.engine.Limit(depth=0), multipv=3)
        if result is None:
            print(f"Error analyzing position: {fen}")
            return ["N/A", "N/A", "N/A"]
        top_moves = [info.get("pv")[0] if info.get("pv") else "N/A" for info in result]
        top_moves.extend(["N/A"] * (3 - len(top_moves)))  # Fill with placeholders if fewer than 3 moves
    return top_moves

def generate_and_save_positions(stockfish_path, num_positions):
    positions = []
    for _ in range(num_positions):
        board = chess.Board()
        board = generate_random_move(board, max_depth=200)
        fen = board.fen()
        top_moves = get_top_moves(stockfish_path, fen)
        positions.append((fen, *top_moves))

    with open('tests/top-3-moves.txt', 'w') as file:
        for position in positions:
            file.write(f"{position[0]} | {position[1]} | {position[2]} | {position[3]}\n")

if __name__ == "__main__":
    stockfish_path = "./stockfish/stockfish.exe"  # Replace with the actual path to Stockfish
    num_positions = 5000
    generate_and_save_positions(stockfish_path, num_positions)

# %%
def test_engine(num_positions):
    correct_guesses = 0

    with open('tests/top-3-moves.txt', 'r') as file:
        for line in file:
            parts = line.strip().split(" | ")
            fen = parts[0]
            stockfish_moves = parts[1:4]

            # Skip positions where all top 3 Stockfish moves are N/A
            if all(move == "N/A" for move in stockfish_moves):
                continue

            # Test your engine's best move function
            board = chess.Board(fen)
            engine_move = best_move(board, depth=3).uci()

            # Check if the engine move matches any of Stockfish's top 3 moves
            if engine_move in stockfish_moves:
                correct_guesses += 1
                print(f"Correct Guess! Position: {fen}, Engine Move: {engine_move}, Stockfish Moves: {stockfish_moves}")

    accuracy = (correct_guesses / num_positions) * 100
    print(f"\nAccuracy: {accuracy:.2f}%")

if __name__ == "__main__":
    num_positions = 5000
    test_engine(num_positions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 29
#      27 stockfish_path = "./stockfish/stockfish.exe"  # Replace with the actual path to Stockfish
#      28 num_positions = 100
# ---> 29 test_engine(stockfish_path, num_positions)
#
# Cell In[73], line 16, in test_engine(stockfish_path, num_positions)
#      14 # Test your engine's best move function
#      15 board = chess.Board(fen)
# ---> 16 engine_move = best_move(board, depth=3).uci()
#      18 # Check if the engine move matches any of Stockfish's top 3 moves
#      19 if engine_move in stockfish_moves:
#
# TypeError: best_move() missing 1 required positional argument: 'start_time'

# %% [markdown]
# # UCI VERSION

# %%
import chess
import chess.polyglot
import time

piece_values_midgame = {
        chess.PAWN: 82,
        chess.KNIGHT: 337,
        chess.BISHOP: 365,
        chess.ROOK: 477,
        chess.QUEEN: 1025,
        chess.KING: 0
    }

piece_values_endgame = {
        chess.PAWN: 94,
        chess.KNIGHT: 281,
        chess.BISHOP: 297,
        chess.ROOK: 512,
        chess.QUEEN: 936,
        chess.KING: 0
    }

piece_square_tables_midgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
-11,  34,  126,  68,  95,  61,  134,  98,
-20,  25,  56,  65,  31,  26,  7,  -6,
-23,  17,  12,  23,  21,  6,  13,  -14,
-25,  10,  6,  17,  12,  -5,  -2,  -27,
-12,  33,  3,  3,  -10,  -4,  -4,  -26,
-22,  38,  24,  -15,  -23,  -20,  -1,  -35,
0,  0,  0,  0,  0,  0,  0,  0
    ],

    chess.KNIGHT:
    [
-107,  -15,  -97,  61,  -49,  -34,  -89,  -167,
-17,  7,  62,  23,  36,  72,  -41,  -73,
44,  73,  129,  84,  65,  37,  60,  -47,
22,  18,  69,  37,  53,  19,  17,  -9,
-8,  21,  19,  28,  13,  16,  4,  -13,
-16,  25,  17,  19,  10,  12,  -9,  -23,
-19,  -14,  18,  -1,  -3,  -12,  -53,  -29,
-23,  -19,  -28,  -17,  -33,  -58,  -21,  -105,
    ],

    chess.BISHOP:
    [
-8,  7,  -42,  -25,  -37,  -82,  4,  -29,
-47,  18,  59,  30,  -13,  -18,  16,  -26,
-2,  37,  50,  35,  40,  43,  37,  -16,
-2,  7,  37,  37,  50,  19,  5,  -4,
4,  10,  12,  34,  26,  13,  13,  -6,
10,  18,  27,  14,  15,  15,  15,  0,
1,  33,  21,  7,  0,  16,  15,  4,
-21,  -39,  -12,  -13,  -21,  -14,  -3,  -33,
    ],

    chess.ROOK:
    [
43,  31,  9,  63,  51,  32,  42,  32,
44,  26,  67,  80,  62,  58,  32,  27,
16,  61,  45,  17,  36,  26,  19,  -5,
-20,  -8,  35,  24,  26,  7,  -11,  -24,
-23,  6,  -7,  9,  -1,  -12,  -26,  -36,
-33,  -5,  0,  3,  -17,  -16,  -25,  -45,
-71,  -6,  11,  -1,  -9,  -20,  -16,  -44,
-26,  -37,  7,  16,  17,  1,  -13,  -19,
    ],

    chess.QUEEN:
    [
45,  43,  44,  59,  12,  29,  0,  -28,
54,  28,  57,  -16,  1,  -5,  -39,  -24,
57,  47,  56,  29,  8,  7,  -17,  -13,
1,  -2,  17,  -1,  -16,  -16,  -27,  -27,
-3,  3,  -4,  -2,  -10,  -9,  -26,  -9,
5,  14,  2,  -5,  -2,  -11,  2,  -14,
1,  -3,  15,  8,  2,  11,  -8,  -35,
-50,  -31,  -25,  -15,  10,  -9,  -18,  -1,
    ],

    chess.KING:
    [
13,  2,  -34,  -56,  -15,  16,  23,  -65,
-29,  -38,  -4,  -8,  -7,  -20,  -1,  29,
-22,  22,  6,  -20,  -16,  2,  24,  -9,
-36,  -14,  -25,  -30,  -27,  -12,  -20,  -17,
-51,  -33,  -44,  -46,  -39,  -27,  -1,  -49,
-27,  -15,  -30,  -44,  -46,  -22,  -14,  -14,
8,  9,  -16,  -43,  -64,  -8,  7,  1,
14,  24,  -28,  -44,  -54,  12,  36,  -15,
    ],

}

piece_square_tables_endgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
187,  165,  132,  147,  134,  158,  173,  178,
84,  82,  53,  56,  67,  85,  100,  94,
17,  17,  4,  -2,  5,  13,  24,  32,
-1,  3,  -8,  -7,  -7,  -3,  9,  13,
-8,  -1,  -5,  0,  1,  -6,  7,  4,
-7,  2,  0,  13,  10,  8,  8,  13,
0,  0,  0,  0,  0,  0,  0,  0,
    ],

    chess.KNIGHT:
    [
-99,  -63,  -27,  -31,  -28,  -13,  -38,  -58,
-52,  -24,  -25,  -9,  -2,  -25,  -8,  -25,
-41,  -19,  -9,  -1,  9,  10,  -20,  -24,
-18,  8,  11,  22,  22,  22,  3,  -17,
-18,  4,  17,  16,  25,  16,  -6,  -18,
-22,  -20,  -3,  10,  15,  -1,  -3,  -23,
-44,  -23,  -20,  -2,  -5,  -10,  -20,  -42,
-64,  -50,  -18,  -22,  -15,  -23,  -51,  -29,
    ],

    chess.BISHOP:
    [
-24,  -17,  -9,  -7,  -8,  -11,  -21,  -14,
-14,  -4,  -13,  -3,  -12,  7,  -4,  -8,
4,  0,  6,  -2,  -1,  0,  -8,  2,
2,  3,  10,  14,  9,  12,  9,  -3,
-9,  -3,  10,  7,  19,  13,  3,  -6,
-15,  -7,  3,  13,  10,  8,  -3,  -12,
-27,  -15,  -9,  4,  -1,  -7,  -18,  -14,
-17,  -5,  -16,  -9,  -5,  -23,  -9,  -23,
    ],

    chess.ROOK:
    [
5,  8,  12,  12,  15,  18,  10,  13,
3,  8,  3,  -3,  11,  13,  13,  11,
-3,  -5,  -3,  4,  5,  7,  7,  7,
2,  -1,  1,  2,  1,  13,  3,  4,
-11,  -8,  -6,  -5,  4,  8,  5,  3,
-16,  -8,  -12,  -7,  -1,  -5,  0,  -4,
-3,  -11,  -9,  -9,  2,  0,  -6,  -6,
-20,  4,  -13,  -5,  -1,  3,  2,  -9,
    ],

    chess.QUEEN:
    [
20,  10,  19,  27,  27,  22,  22,  -9,
0,  30,  25,  58,  41,  32,  20,  -17,
9,  19,  35,  47,  49,  9,  6,  -20,
36,  57,  40,  57,  45,  24,  22,  3,
23,  39,  34,  31,  47,  19,  28,  -18,
5,  10,  17,  9,  6,  15,  -27,  -16,
-32,  -36,  -23,  -16,  -16,  -30,  -23,  -22,
-41,  -20,  -32,  -5,  -43,  -22,  -28,  -33,
    ],

    chess.KING:
    [
-17,  4,  15,  -11,  -18,  -18,  -35,  -74,
11,  23,  38,  17,  17,  14,  17,  -12,
13,  44,  45,  20,  15,  23,  17,  10,
3,  26,  33,  26,  27,  24,  22,  -8,
-11,  9,  23,  27,  24,  21,  -4,  -18,
-9,  7,  16,  23,  21,  11,  -3,  -19,
-17,  -5,  4,  14,  13,  4,  -11,  -27,
-43,  -24,  -14,  -28,  -11,  -21,  -34,  -53,
    ],

}

def evaluate_board(board):
    midgame = not is_endgame(board)

    if midgame:
        piece_values = piece_values_midgame
        piece_square_tables = piece_square_tables_midgame
    else:
        piece_values = piece_values_endgame
        piece_square_tables = piece_square_tables_endgame

    evaluation = 0

    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece is not None:
            sign = 1 if piece.color == chess.WHITE else -1
            piece_type = piece.piece_type

            color = piece.color

            if color == chess.WHITE:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][63 - square]
            else:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][square]

            evaluation += sign * (piece_values[piece_type] + square_value)

    return evaluation


def is_endgame(board):
  # Check if there are no major pieces
  no_major_pieces = (
      sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0)
  if no_major_pieces:
    return True

  # Check for two rooks and no queen
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) <= 1):
    return True

  # Check for two queens or less, kings, and no other pieces except pawns
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0):
    return True

  # If none of the above conditions are met, return False
  return False

def quiescence_search(board, color, alpha, beta, ply):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    stand_pat = color * evaluate_board(board)
    if stand_pat >= beta:
        return beta
    if alpha < stand_pat:
        alpha = stand_pat

    # Sort capture moves using MVV-LVA ordering
    capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
    ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
        board.pop()

        if score >= beta:
            return beta
        if score > alpha:
            alpha = score

    return alpha

def mvv_lva(board, move):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    # Get the piece at the destination square, or None if the square is empty
    to_piece = board.piece_at(move.to_square)

    # Get the piece at the source square, or None if the square is empty
    from_piece = board.piece_at(move.from_square)

    # Calculate MVV-LVA score for a move
    if to_piece is not None and from_piece is not None:
        return piece_values_midgame[to_piece.piece_type] - piece_values_midgame[from_piece.piece_type]
    else:
        # If either square is empty, return a low score
        return -1  # You can adjust this value based on your preferences


def negamax(board, depth, color, alpha, beta, ply, nodes):
    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0, nodes

    if board.is_checkmate():
            return -10000+ply, nodes
        
    if depth == 0 or board.is_game_over():
        return quiescence_search(board, color, alpha, beta, ply+1), nodes

    # Sort legal moves using MVV-LVA ordering
    ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        nodes += 1
        value, nodes = negamax(board, depth - 1, -color, -beta, -alpha, ply+1, nodes)
        value = -value
        board.pop()

        alpha = max(alpha, value)
        if alpha >= beta:
            break

    return alpha, nodes


def best_move(board, start_time, depth):
    if board.turn == chess.WHITE:
        color = 1
    else: 
        color = -1

    alpha = float('-inf')
    beta = float('inf')
    ply = 0
    nodes = 0

    opening_book_path = 'book/komodo.bin'  # Use the .bin file for polyglot
    # Try moves from the opening book first
    with chess.polyglot.open_reader(opening_book_path) as reader:
        for entry in reader.find_all(board):
            move = entry.move
            if move in board.legal_moves:
                return move  # Return a move from the opening book

    best_mv = None

    for current_depth in range(1, depth + 1):
        ordered_moves = sorted(
            board.legal_moves,
            key=lambda move: (
                -piece_values_midgame[board.piece_at(move.to_square).piece_type]
                if board.piece_at(move.to_square) is not None else 0,
                -piece_values_midgame[board.piece_at(move.from_square).piece_type]
                if board.piece_at(move.from_square) is not None else 0
            )
        )

        for move in ordered_moves:
            board.push(move)
            nodes += 1
            if board.is_checkmate():
                return move
            eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
            eval = -eval
            board.pop()

            if eval > alpha:
                alpha = eval
                best_mv = move

        elapsed_time = time.time() - start_time

        start_time = time.time()

        print(f"info depth {current_depth} score cp {alpha} nps {int(nodes/elapsed_time)} time {int(elapsed_time*100)} pv {best_mv.uci()}")

    return best_mv


def play_chess():
    board = chess.Board()

    while True:
        line = input()
        if line == "uci":
            print("id name PyGo")
            print("id author Chess123easy")
            print("uciok")
        elif line == "isready":
            print("readyok")
        elif line.startswith("position startpos"):
            board = chess.Board()
            if "moves" in line:
                _, moves_part = line.split("moves")
                moves = moves_part.strip().split()
                for move in moves:
                    board.push_uci(move)
        elif line.startswith("position fen"):
            _, fen = line.split("fen", 1)
            board.set_fen(fen.strip())
        elif line.startswith("go"):
            start_time = time.time()  # Start the timer
            move = best_move(board, start_time, depth=3).uci()
            print(f"bestmove {move}")
        elif line == "quit":
            break

if __name__ == "__main__":
    play_chess()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 398
#     395             break
#     397 if __name__ == "__main__":
# --> 398     play_chess()
#
# Cell In[4], line 373, in play_chess()
#     370 board = chess.Board()
#     372 while True:
# --> 373     line = input()
#     374     if line == "uci":
#     375         print("id name PyGo")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# POSITION 3r1r1k/1b2b2p/1q2pp2/n1n3p1/p5N1/P4PBP/BPPQ2P1/1R2R1K1 w - - 7 26
# NPS TO BEAT:
# D1 101
# D2 33
# D3 160
# TIME TO BEAT:
# D1 57
# D2 802
# D3 2415

# %%
def best_move(board, start_time, depth):
    if board.turn == chess.WHITE:
        color = 1
    else: 
        color = -1

    alpha = float('-inf')
    beta = float('inf')
    ply = 0
    nodes = 0

    opening_book_path = 'book/komodo.bin'  # Use the .bin file for polyglot
    # Try moves from the opening book first
    with chess.polyglot.open_reader(opening_book_path) as reader:
        for entry in reader.find_all(board):
            move = entry.move
            if move in board.legal_moves:
                return move  # Return a move from the opening book

    best_mv = None

    for current_depth in range(1, depth + 1):
        ordered_moves = sorted(
            board.legal_moves,
            key=lambda move: (
                -piece_values_midgame[board.piece_at(move.to_square).piece_type]
                if board.piece_at(move.to_square) is not None else 0,
                -piece_values_midgame[board.piece_at(move.from_square).piece_type]
                if board.piece_at(move.from_square) is not None else 0
            )
        )

        for move in ordered_moves:
            board.push(move)
            nodes += 1
            if board.is_checkmate():
                return move
            eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
            eval = -eval
            board.pop()

            if eval > alpha:
                alpha = eval
                best_mv = move

        elapsed_time = time.time() - start_time

        start_time = time.time()

        print(f"info depth {current_depth} score cp {alpha} nps {int(nodes/max(0.01, elapsed_time))} time {int(elapsed_time*100)} pv {best_mv.uci()}")

    return best_mv

def test_engine(stockfish_path, num_positions):
    correct_guesses = 0

    with open('tests/top-3-moves.txt', 'r') as file:
        for line in file:
            parts = line.strip().split(" | ")
            fen = parts[0]
            stockfish_moves = parts[1:4]

            # Skip positions where all top 3 Stockfish moves are N/A
            if all(move == "N/A" for move in stockfish_moves):
                continue

            # Test your engine's best move function
            board = chess.Board(fen)
            engine_move = best_move(board, time.time(), depth=1).uci()

            # Check if the engine move matches any of Stockfish's top 3 moves
            if engine_move in stockfish_moves:
                correct_guesses += 1
                print(f"Correct Guess! Position: {fen}, Engine Move: {engine_move}, Stockfish Moves: {stockfish_moves}")

    accuracy = (correct_guesses / num_positions) * 100
    print(f"\nAccuracy: {accuracy:.2f}%")

if __name__ == "__main__":
    stockfish_path = "./stockfish/stockfish.exe"  # Replace with the actual path to Stockfish
    num_positions = 5000
    test_engine(stockfish_path, num_positions)
# Out:
# info depth 1 score cp 1582 nps 400 time 0 pv h7e7
# Correct Guess! Position: 8/3kQ2q/P2p2R1/2p1nP1p/ppP5/4p2b/P3P3/2b3K1 b - - 11 83, Engine Move: h7e7, Stockfish Moves: ['h7e7', 'd7e7', 'd7c8']
# info depth 1 score cp 1345 nps 338 time 11 pv b4a3
# Correct Guess! Position: 1n3brk/2q5/r2ppPpp/2p5/PpPP3P/RP2K2N/5Pb1/1BB2R2 b - - 0 33, Engine Move: b4a3, Stockfish Moves: ['c5d4', 'b4a3', 'g2f1']
# info depth 1 score cp 938 nps 357 time 8 pv g4f5
# Correct Guess! Position: rnb1kbnr/2p2ppp/3p4/pp2pq2/3P2P1/N7/PPPBP2P/R2QKBNR w KQkq - 0 7, Engine Move: g4f5, Stockfish Moves: ['g4f5', 'a3b5', 'f1g2']
# info depth 1 score cp 162 nps 562 time 3 pv f8e7
# Correct Guess! Position: 1n1k1B1N/4b3/2p5/2p2pQ1/1nP3p1/r2p2P1/3K4/8 w - - 2 66, Engine Move: f8e7, Stockfish Moves: ['h8f7', 'g5e7', 'f8e7']
# info depth 1 score cp -1543 nps 200 time 0 pv h8g7
# Correct Guess! Position: 2BN3k/8/4B3/8/2PPp1P1/4p3/4K3/5R2 b - - 4 79, Engine Move: h8g7, Stockfish Moves: ['h8g7', 'h8h7', 'N/A']
# info depth 1 score cp -1073 nps 576 time 3 pv b5a6
# Correct Guess! Position: 4k2r/5n2/q1p1rP1p/1P2P1NP/p3K1P1/1np5/8/1R6 w - - 1 56, Engine Move: b5a6, Stockfish Moves: ['g5e6', 'b5a6', 'g5f7']
# info depth 1 score cp 168 nps 750 time 3 pv f1g1
# Correct Guess! Position: 3k3B/7p/3n3P/p2R4/5b2/8/8/5Kb1 w - - 3 95, Engine Move: f1g1, Stockfish Moves: ['f1g1', 'h8f6', 'h8c3']
# info depth 1 score cp 84 nps 26 time 109 pv d7e6
# Correct Guess! Position: 1rb1q2r/1p1pkp2/n2bN1pp/p3pP2/2p1P1n1/1PP4P/P2P2B1/RNBQK2R b KQ - 2 20, Engine Move: d7e6, Stockfish Moves: ['d7e6', 'g4e3', 'g4f2']
# info depth 1 score cp -126 nps 760 time 3 pv c4d5
# info depth 1 score cp -84 nps 92 time 24 pv h5h4
# Correct Guess! Position: r1bqkbnr/p1npp3/5pp1/1pp4p/1P2BP2/4P1K1/P1PP2PP/RNBQ2NR b kq - 1 9, Engine Move: h5h4, Stockfish Moves: ['h5h4', 'g6g5', 'f8g7']
# info depth 1 score cp 39 nps 364 time 10 pv b3b7
# Correct Guess! Position: 2n1r2k/1q4r1/7n/8/3pP3/1QPK1NP1/1b3PRN/5R2 w - - 0 60, Engine Move: b3b7, Stockfish Moves: ['b3b7', 'f3d2', 'b3d5']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 82
#      80 stockfish_path = "./stockfish/stockfish.exe"  # Replace with the actual path to Stockfish
#      81 num_positions = 5000
# ---> 82 test_engine(stockfish_path, num_positions)
#
# Cell In[6], line 69, in test_engine(stockfish_path, num_positions)
#      67 # Test your engine's best move function
#      68 board = chess.Board(fen)
# ---> 69 engine_move = best_move(board, time.time(), depth=1).uci()
#      71 # Check if the engine move matches any of Stockfish's top 3 moves
#      72 if engine_move in stockfish_moves:
#
# Cell In[6], line 38, in best_move(board, start_time, depth)
#      36 if board.is_checkmate():
#      37     return move
# ---> 38 eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
#      39 eval = -eval
#      40 board.pop()
#
# Cell In[4], line 296, in negamax(board, depth, color, alpha, beta, ply, nodes)
#     293         return -10000+ply, nodes
#     295 if depth == 0 or board.is_game_over():
# --> 296     return quiescence_search(board, color, alpha, beta, ply+1), nodes
#     298 # Sort legal moves using MVV-LVA ordering
#     299 ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)
#
# Cell In[4], line 251, in quiescence_search(board, color, alpha, beta, ply)
#     248     alpha = stand_pat
#     250 # Sort capture moves using MVV-LVA ordering
# --> 251 capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
#     252 ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)
#     254 for move in ordered_moves:
#
# Cell In[4], line 251, in <listcomp>(.0)
#     248     alpha = stand_pat
#     250 # Sort capture moves using MVV-LVA ordering
# --> 251 capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
#     252 ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)
#     254 for move in ordered_moves:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\chess\__init__.py:3194, in Board.is_capture(self, move)
#    3192 """Checks if the given pseudo-legal move is a capture."""
#    3193 touched = BB_SQUARES[move.from_square] ^ BB_SQUARES[move.to_square]
# -> 3194 return bool(touched & self.occupied_co[not self.turn]) or self.is_en_passant(move)
#
# KeyboardInterrupt:

# %%
def load_test_positions(file_path):
    positions = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' | ')
            fen = parts[0]
            move = parts[1]
            positions.append((fen, move))
    return positions

def test():
    file_path = 'tests/mate-in-2-fens.txt'
    positions = load_test_positions(file_path)

    correct_moves = 0
    total_positions = len(positions)

    for fen, expected_move in positions:
        board = chess.Board(fen)
        best_move_result = best_move(board, time.time(), depth=3).uci()
        if best_move_result == expected_move:
            correct_moves += 1
        print(f"Position: {fen}\nExpected Move: {expected_move}\nActual Move: {best_move_result}\n")

    accuracy = (correct_moves / total_positions) * 100
    print(f"\nAccuracy: {accuracy:.2f}%")

if __name__ == "__main__":
    test()
# Out:
# info depth 1 score cp 994 nps 1907 time 1 pv a5f5
# info depth 2 score cp 1022 nps 857 time 9 pv a5f5
# info depth 3 score cp 9997 nps 1103 time 74 pv a5a7
# Position: 8/4k3/1R3p2/R7/8/8/8/8 w - - 0 1
# Expected Move: a5a7
# Actual Move: a5a7
#
# info depth 1 score cp 1028 nps 2350 time 1 pv h2d2
# info depth 2 score cp 1038 nps 1783 time 4 pv h2d2
# info depth 3 score cp 9997 nps 1054 time 74 pv d3e3
# Position: 8/8/8/8/8/3k4/7q/5K2 b - - 0 1
# Expected Move: d3e3
# Actual Move: d3e3
#
# info depth 1 score cp 629 nps 2000 time 0 pv c7d5
# info depth 2 score cp 648 nps 5350 time 1 pv c7d5
# info depth 3 score cp 9997 nps 1519 time 18 pv c7a6
# Position: 1k6/2NB4/1K6/8/8/8/8/8 w - - 0 1
# Expected Move: c7a6
# Actual Move: c7a6
#
# info depth 1 score cp -934 nps 1343 time 1 pv g2g6
# info depth 2 score cp 9996 nps 385 time 22 pv f3e3
# info depth 3 score cp 9997 nps 719 time 100 pv f3e3
# Position: 8/2p1p3/2qbn3/2pkp3/8/1P3K2/6Q1/8 w - - 0 1
# Expected Move: f3e3
# Actual Move: f3e3
#
# info depth 1 score cp 596 nps 900 time 0 pv f7f8r
# info depth 2 score cp 596 nps 2400 time 0 pv f7f8r
# info depth 3 score cp 9997 nps 1959 time 5 pv f7f8r
# Position: 8/5P1k/5K2/8/8/8/8/8 w - - 0 1
# Expected Move: f7f8r
# Actual Move: f7f8r
#
# info depth 1 score cp 831 nps 2200 time 0 pv f7e5
# info depth 2 score cp 831 nps 1855 time 3 pv f7e5
# info depth 3 score cp 9997 nps 1191 time 51 pv f4h4
# Position: 8/5n1K/5k2/8/5r2/8/8/8 b - - 0 1
# Expected Move: f4h4
# Actual Move: f4h4
#
# info depth 1 score cp 1363 nps 631 time 3 pv c7b7
# info depth 2 score cp 9996 nps 1230 time 4 pv c7a7
# info depth 3 score cp 9997 nps 1213 time 36 pv c7a7
# Position: KB6/2rq4/k1p5/8/3p4/8/8/8 b - - 0 1
# Expected Move: c7a7
# Actual Move: c7a7
#
# info depth 1 score cp 101 nps 357 time 9 pv d1h5
# info depth 2 score cp 9996 nps 232 time 45 pv d1h5
# info depth 3 score cp 9997 nps 605 time 196 pv d1h5
# Position: rnbqkb1r/ppppp2p/5p1n/4N1p1/4P3/8/PPPP1PPP/RNBQKB1R w KQkq - 0 1
# Expected Move: d1h5
# Actual Move: d1h5
#
# info depth 1 score cp 282 nps 1190 time 1 pv c8d7
# info depth 2 score cp 283 nps 608 time 15 pv c8d7
# info depth 3 score cp 9997 nps 1009 time 46 pv a1a6
# Position: kbK5/pp6/1P6/8/8/8/8/R7 w - - 0 1
# Expected Move: a1a6
# Actual Move: a1a6
#
#
# Accuracy: 100.00%

# %% [markdown]
# # Time Management

# %%
import chess
import chess.polyglot
import time

piece_values_midgame = {
        chess.PAWN: 82,
        chess.KNIGHT: 337,
        chess.BISHOP: 365,
        chess.ROOK: 477,
        chess.QUEEN: 1025,
        chess.KING: 0
    }

piece_values_endgame = {
        chess.PAWN: 94,
        chess.KNIGHT: 281,
        chess.BISHOP: 297,
        chess.ROOK: 512,
        chess.QUEEN: 936,
        chess.KING: 0
    }

piece_square_tables_midgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
-11,  34,  126,  68,  95,  61,  134,  98,
-20,  25,  56,  65,  31,  26,  7,  -6,
-23,  17,  12,  23,  21,  6,  13,  -14,
-25,  10,  6,  17,  12,  -5,  -2,  -27,
-12,  33,  3,  3,  -10,  -4,  -4,  -26,
-22,  38,  24,  -15,  -23,  -20,  -1,  -35,
0,  0,  0,  0,  0,  0,  0,  0
    ],

    chess.KNIGHT:
    [
-107,  -15,  -97,  61,  -49,  -34,  -89,  -167,
-17,  7,  62,  23,  36,  72,  -41,  -73,
44,  73,  129,  84,  65,  37,  60,  -47,
22,  18,  69,  37,  53,  19,  17,  -9,
-8,  21,  19,  28,  13,  16,  4,  -13,
-16,  25,  17,  19,  10,  12,  -9,  -23,
-19,  -14,  18,  -1,  -3,  -12,  -53,  -29,
-23,  -19,  -28,  -17,  -33,  -58,  -21,  -105,
    ],

    chess.BISHOP:
    [
-8,  7,  -42,  -25,  -37,  -82,  4,  -29,
-47,  18,  59,  30,  -13,  -18,  16,  -26,
-2,  37,  50,  35,  40,  43,  37,  -16,
-2,  7,  37,  37,  50,  19,  5,  -4,
4,  10,  12,  34,  26,  13,  13,  -6,
10,  18,  27,  14,  15,  15,  15,  0,
1,  33,  21,  7,  0,  16,  15,  4,
-21,  -39,  -12,  -13,  -21,  -14,  -3,  -33,
    ],

    chess.ROOK:
    [
43,  31,  9,  63,  51,  32,  42,  32,
44,  26,  67,  80,  62,  58,  32,  27,
16,  61,  45,  17,  36,  26,  19,  -5,
-20,  -8,  35,  24,  26,  7,  -11,  -24,
-23,  6,  -7,  9,  -1,  -12,  -26,  -36,
-33,  -5,  0,  3,  -17,  -16,  -25,  -45,
-71,  -6,  11,  -1,  -9,  -20,  -16,  -44,
-26,  -37,  7,  16,  17,  1,  -13,  -19,
    ],

    chess.QUEEN:
    [
45,  43,  44,  59,  12,  29,  0,  -28,
54,  28,  57,  -16,  1,  -5,  -39,  -24,
57,  47,  56,  29,  8,  7,  -17,  -13,
1,  -2,  17,  -1,  -16,  -16,  -27,  -27,
-3,  3,  -4,  -2,  -10,  -9,  -26,  -9,
5,  14,  2,  -5,  -2,  -11,  2,  -14,
1,  -3,  15,  8,  2,  11,  -8,  -35,
-50,  -31,  -25,  -15,  10,  -9,  -18,  -1,
    ],

    chess.KING:
    [
13,  2,  -34,  -56,  -15,  16,  23,  -65,
-29,  -38,  -4,  -8,  -7,  -20,  -1,  29,
-22,  22,  6,  -20,  -16,  2,  24,  -9,
-36,  -14,  -25,  -30,  -27,  -12,  -20,  -17,
-51,  -33,  -44,  -46,  -39,  -27,  -1,  -49,
-27,  -15,  -30,  -44,  -46,  -22,  -14,  -14,
8,  9,  -16,  -43,  -64,  -8,  7,  1,
14,  24,  -28,  -44,  -54,  12,  36,  -15,
    ],

}

piece_square_tables_endgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
187,  165,  132,  147,  134,  158,  173,  178,
84,  82,  53,  56,  67,  85,  100,  94,
17,  17,  4,  -2,  5,  13,  24,  32,
-1,  3,  -8,  -7,  -7,  -3,  9,  13,
-8,  -1,  -5,  0,  1,  -6,  7,  4,
-7,  2,  0,  13,  10,  8,  8,  13,
0,  0,  0,  0,  0,  0,  0,  0,
    ],

    chess.KNIGHT:
    [
-99,  -63,  -27,  -31,  -28,  -13,  -38,  -58,
-52,  -24,  -25,  -9,  -2,  -25,  -8,  -25,
-41,  -19,  -9,  -1,  9,  10,  -20,  -24,
-18,  8,  11,  22,  22,  22,  3,  -17,
-18,  4,  17,  16,  25,  16,  -6,  -18,
-22,  -20,  -3,  10,  15,  -1,  -3,  -23,
-44,  -23,  -20,  -2,  -5,  -10,  -20,  -42,
-64,  -50,  -18,  -22,  -15,  -23,  -51,  -29,
    ],

    chess.BISHOP:
    [
-24,  -17,  -9,  -7,  -8,  -11,  -21,  -14,
-14,  -4,  -13,  -3,  -12,  7,  -4,  -8,
4,  0,  6,  -2,  -1,  0,  -8,  2,
2,  3,  10,  14,  9,  12,  9,  -3,
-9,  -3,  10,  7,  19,  13,  3,  -6,
-15,  -7,  3,  13,  10,  8,  -3,  -12,
-27,  -15,  -9,  4,  -1,  -7,  -18,  -14,
-17,  -5,  -16,  -9,  -5,  -23,  -9,  -23,
    ],

    chess.ROOK:
    [
5,  8,  12,  12,  15,  18,  10,  13,
3,  8,  3,  -3,  11,  13,  13,  11,
-3,  -5,  -3,  4,  5,  7,  7,  7,
2,  -1,  1,  2,  1,  13,  3,  4,
-11,  -8,  -6,  -5,  4,  8,  5,  3,
-16,  -8,  -12,  -7,  -1,  -5,  0,  -4,
-3,  -11,  -9,  -9,  2,  0,  -6,  -6,
-20,  4,  -13,  -5,  -1,  3,  2,  -9,
    ],

    chess.QUEEN:
    [
20,  10,  19,  27,  27,  22,  22,  -9,
0,  30,  25,  58,  41,  32,  20,  -17,
9,  19,  35,  47,  49,  9,  6,  -20,
36,  57,  40,  57,  45,  24,  22,  3,
23,  39,  34,  31,  47,  19,  28,  -18,
5,  10,  17,  9,  6,  15,  -27,  -16,
-32,  -36,  -23,  -16,  -16,  -30,  -23,  -22,
-41,  -20,  -32,  -5,  -43,  -22,  -28,  -33,
    ],

    chess.KING:
    [
-17,  4,  15,  -11,  -18,  -18,  -35,  -74,
11,  23,  38,  17,  17,  14,  17,  -12,
13,  44,  45,  20,  15,  23,  17,  10,
3,  26,  33,  26,  27,  24,  22,  -8,
-11,  9,  23,  27,  24,  21,  -4,  -18,
-9,  7,  16,  23,  21,  11,  -3,  -19,
-17,  -5,  4,  14,  13,  4,  -11,  -27,
-43,  -24,  -14,  -28,  -11,  -21,  -34,  -53,
    ],

}

def evaluate_board(board):
    midgame = not is_endgame(board)

    if midgame:
        piece_values = piece_values_midgame
        piece_square_tables = piece_square_tables_midgame
    else:
        piece_values = piece_values_endgame
        piece_square_tables = piece_square_tables_endgame

    evaluation = 0

    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece is not None:
            sign = 1 if piece.color == chess.WHITE else -1
            piece_type = piece.piece_type

            color = piece.color

            if color == chess.WHITE:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][63 - square]
            else:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][square]

            evaluation += sign * (piece_values[piece_type] + square_value)

    return evaluation


def is_endgame(board):
  # Check if there are no major pieces
  no_major_pieces = (
      sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0)
  if no_major_pieces:
    return True

  # Check for two rooks and no queen
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) <= 1):
    return True

  # Check for two queens or less, kings, and no other pieces except pawns
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0):
    return True

  # If none of the above conditions are met, return False
  return False

def quiescence_search(board, color, alpha, beta, ply):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    stand_pat = color * evaluate_board(board)
    if stand_pat >= beta:
        return beta
    if alpha < stand_pat:
        alpha = stand_pat

    # Sort capture moves using MVV-LVA ordering
    capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
    ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
        board.pop()

        if score >= beta:
            return beta
        if score > alpha:
            alpha = score

    return alpha

def mvv_lva(board, move):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    # Get the piece at the destination square, or None if the square is empty
    to_piece = board.piece_at(move.to_square)

    # Get the piece at the source square, or None if the square is empty
    from_piece = board.piece_at(move.from_square)

    # Calculate MVV-LVA score for a move
    if to_piece is not None and from_piece is not None:
        return piece_values_midgame[to_piece.piece_type] - piece_values_midgame[from_piece.piece_type]
    else:
        # If either square is empty, return a low score
        return -1  # You can adjust this value based on your preferences


def negamax(board, depth, color, alpha, beta, ply, nodes):
    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0, nodes

    if board.is_checkmate():
            return -10000+ply, nodes
        
    if depth == 0 or board.is_game_over():
        return quiescence_search(board, color, alpha, beta, ply+1), nodes

    # Sort legal moves using MVV-LVA ordering
    ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        nodes += 1
        value, nodes = negamax(board, depth - 1, -color, -beta, -alpha, ply+1, nodes)
        value = -value
        board.pop()

        alpha = max(alpha, value)
        if alpha >= beta:
            break

    return alpha, nodes


def best_move(board, start_time, max_time, depth):
    if board.turn == chess.WHITE:
        color = 1
    else: 
        color = -1

    alpha = float('-inf')
    beta = float('inf')
    ply = 0
    nodes = 0

    opening_book_path = 'book/komodo.bin'  # Use the .bin file for polyglot
    # Try moves from the opening book first
    with chess.polyglot.open_reader(opening_book_path) as reader:
        for entry in reader.find_all(board):
            move = entry.move
            if move in board.legal_moves:
                return move  # Return a move from the opening book

    best_mv = None

    for current_depth in range(1, depth + 1):
        elapsed_time = time.time() - start_time
        if elapsed_time >= max_time:
            return best_mv  # Exit the function immediately if max_time is reached
        ordered_moves = sorted(
            board.legal_moves,
            key=lambda move: (
                -piece_values_midgame[board.piece_at(move.to_square).piece_type]
                if board.piece_at(move.to_square) is not None else 0,
                -piece_values_midgame[board.piece_at(move.from_square).piece_type]
                if board.piece_at(move.from_square) is not None else 0
            )
        )

        for move in ordered_moves:
            board.push(move)
            nodes += 1
            if board.is_checkmate():
                return move
            eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
            eval = -eval
            board.pop()

            if eval > alpha:
                alpha = eval
                best_mv = move

        print(f"info depth {current_depth} score cp {alpha} nps {int(nodes/max(0.01, elapsed_time))} time {int(elapsed_time*100)} pv {best_mv.uci()}")

    return best_mv


def calculateMaxTime(remaining_time):
    return remaining_time / 60

DEFAULT_WTIME = 1000000
DEFAULT_BTIME = 1000000

def parse_parameters(line):
    parameters = line.split()[1:]
    wtime, btime = DEFAULT_WTIME, DEFAULT_BTIME

    for i in range(len(parameters)):
        if parameters[i] == "wtime" and i + 1 < len(parameters):
            wtime = float(parameters[i + 1])
        elif parameters[i] == "btime" and i + 1 < len(parameters):
            btime = float(parameters[i + 1])

    return wtime, btime

def play_chess():
    board = chess.Board()
    remaining_time = 1000000

    while True:
        line = input()
        if line == "uci":
            print("id name PyGo")
            print("id author Chess123easy")
            print("uciok")
        elif line == "isready":
            print("readyok")
        elif line.startswith("position startpos"):
            board = chess.Board()
            if "moves" in line:
                _, moves_part = line.split("moves")
                moves = moves_part.strip().split()
                for move in moves:
                    board.push_uci(move)
        elif line.startswith("position fen"):
            _, fen = line.split("fen", 1)
            board.set_fen(fen.strip())
        elif line.startswith("go"):
            wtime, btime = parse_parameters(line)
            remaining_time = wtime / 1000 if board.turn == chess.WHITE else btime / 1000

            start_time = time.time()
            max_time = calculateMaxTime(remaining_time)
            move = best_move(board, start_time, max_time, depth=3).uci()
            print(f"bestmove {move}")
        elif line == "quit":
            break

if __name__ == "__main__":
    play_chess()
# Out:
#  uci
# id name PyGo
# id author Chess123easy
# uciok
#  position fen r1b2rk1/ppq2pbp/2np1np1/4p3/4P3/1NBB1N2/PPP2PPP/R2Q1RK1 b - - 1 11
#  go
# info depth 1 score cp -4 nps 3700 time 0 pv c8e6
# info depth 2 score cp -4 nps 1071 time 16 pv c8e6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 420
#     417             break
#     419 if __name__ == "__main__":
# --> 420     play_chess()
#
# Cell In[26], line 414, in play_chess()
#     412     start_time = time.time()
#     413     max_time = calculateMaxTime(remaining_time)
# --> 414     move = best_move(board, start_time, max_time, depth=3).uci()
#     415     print(f"bestmove {move}")
#     416 elif line == "quit":
#
# Cell In[26], line 355, in best_move(board, start_time, max_time, depth)
#     353 if board.is_checkmate():
#     354     return move
# --> 355 eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
#     356 eval = -eval
#     357 board.pop()
#
# Cell In[26], line 304, in negamax(board, depth, color, alpha, beta, ply, nodes)
#     302 board.push(move)
#     303 nodes += 1
# --> 304 value, nodes = negamax(board, depth - 1, -color, -beta, -alpha, ply+1, nodes)
#     305 value = -value
#     306 board.pop()
#
# Cell In[26], line 304, in negamax(board, depth, color, alpha, beta, ply, nodes)
#     302 board.push(move)
#     303 nodes += 1
# --> 304 value, nodes = negamax(board, depth - 1, -color, -beta, -alpha, ply+1, nodes)
#     305 value = -value
#     306 board.pop()
#
# Cell In[26], line 296, in negamax(board, depth, color, alpha, beta, ply, nodes)
#     293         return -10000+ply, nodes
#     295 if depth == 0 or board.is_game_over():
# --> 296     return quiescence_search(board, color, alpha, beta, ply+1), nodes
#     298 # Sort legal moves using MVV-LVA ordering
#     299 ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)
#
# Cell In[26], line 256, in quiescence_search(board, color, alpha, beta, ply)
#     254 for move in ordered_moves:
#     255     board.push(move)
# --> 256     score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
#     257     board.pop()
#     259     if score >= beta:
#
# Cell In[26], line 256, in quiescence_search(board, color, alpha, beta, ply)
#     254 for move in ordered_moves:
#     255     board.push(move)
# --> 256     score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
#     257     board.pop()
#     259     if score >= beta:
#
#     [... skipping similar frames: quiescence_search at line 256 (4 times)]
#
# Cell In[26], line 256, in quiescence_search(board, color, alpha, beta, ply)
#     254 for move in ordered_moves:
#     255     board.push(move)
# --> 256     score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
#     257     board.pop()
#     259     if score >= beta:
#
# Cell In[26], line 238, in quiescence_search(board, color, alpha, beta, ply)
#     236 def quiescence_search(board, color, alpha, beta, ply):
# --> 238     if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
#     239             return 0
#     241     if board.is_checkmate():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\chess\__init__.py:2067, in Board.can_claim_draw(self)
#    2060 def can_claim_draw(self) -> bool:
#    2061     """
#    2062     Checks if the player to move can claim a draw by the fifty-move rule or
#    2063     by threefold repetition.
#    2064
#    2065     Note that checking the latter can be slow.
#    2066     """
# -> 2067     return self.can_claim_fifty_moves() or self.can_claim_threefold_repetition()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\chess\__init__.py:2138, in Board.can_claim_threefold_repetition(self)
#    2136 self.push(move)
#    2137 try:
# -> 2138     if transpositions[self._transposition_key()] >= 2:
#    2139         return True
#    2140 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\chess\__init__.py:3681, in Board._transposition_key(self)
#    3677 def _transposition_key(self) -> Hashable:
#    3678     return (self.pawns, self.knights, self.bishops, self.rooks,
#    3679             self.queens, self.kings,
#    3680             self.occupied_co[WHITE], self.occupied_co[BLACK],
# -> 3681             self.turn, self.clean_castling_rights(),
#    3682             self.ep_square if self.has_legal_en_passant() else None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\chess\__init__.py:3240, in Board.clean_castling_rights(self)
#    3235     """
#    3236     Checks if the given pseudo-legal move is a queenside castling move.
#    3237     """
#    3238     return self.is_castling(move) and square_file(move.to_square) < square_file(move.from_square)
# -> 3240 def clean_castling_rights(self) -> Bitboard:
#    3241     """
#    3242     Returns valid castling rights filtered from
#    3243     :data:`~chess.Board.castling_rights`.
#    3244     """
#    3245     if self._stack:
#    3246         # No new castling rights are assigned in a game, so we can assume
#    3247         # they were filtered already.
#
# KeyboardInterrupt:

# %% [markdown]
# # Transposition tables?

# %%
import chess
import chess.polyglot
import time

piece_values_midgame = {
        chess.PAWN: 82,
        chess.KNIGHT: 337,
        chess.BISHOP: 365,
        chess.ROOK: 477,
        chess.QUEEN: 1025,
        chess.KING: 0
    }

piece_values_endgame = {
        chess.PAWN: 94,
        chess.KNIGHT: 281,
        chess.BISHOP: 297,
        chess.ROOK: 512,
        chess.QUEEN: 936,
        chess.KING: 0
    }

piece_square_tables_midgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
-11,  34,  126,  68,  95,  61,  134,  98,
-20,  25,  56,  65,  31,  26,  7,  -6,
-23,  17,  12,  23,  21,  6,  13,  -14,
-25,  10,  6,  17,  12,  -5,  -2,  -27,
-12,  33,  3,  3,  -10,  -4,  -4,  -26,
-22,  38,  24,  -15,  -23,  -20,  -1,  -35,
0,  0,  0,  0,  0,  0,  0,  0
    ],

    chess.KNIGHT:
    [
-107,  -15,  -97,  61,  -49,  -34,  -89,  -167,
-17,  7,  62,  23,  36,  72,  -41,  -73,
44,  73,  129,  84,  65,  37,  60,  -47,
22,  18,  69,  37,  53,  19,  17,  -9,
-8,  21,  19,  28,  13,  16,  4,  -13,
-16,  25,  17,  19,  10,  12,  -9,  -23,
-19,  -14,  18,  -1,  -3,  -12,  -53,  -29,
-23,  -19,  -28,  -17,  -33,  -58,  -21,  -105,
    ],

    chess.BISHOP:
    [
-8,  7,  -42,  -25,  -37,  -82,  4,  -29,
-47,  18,  59,  30,  -13,  -18,  16,  -26,
-2,  37,  50,  35,  40,  43,  37,  -16,
-2,  7,  37,  37,  50,  19,  5,  -4,
4,  10,  12,  34,  26,  13,  13,  -6,
10,  18,  27,  14,  15,  15,  15,  0,
1,  33,  21,  7,  0,  16,  15,  4,
-21,  -39,  -12,  -13,  -21,  -14,  -3,  -33,
    ],

    chess.ROOK:
    [
43,  31,  9,  63,  51,  32,  42,  32,
44,  26,  67,  80,  62,  58,  32,  27,
16,  61,  45,  17,  36,  26,  19,  -5,
-20,  -8,  35,  24,  26,  7,  -11,  -24,
-23,  6,  -7,  9,  -1,  -12,  -26,  -36,
-33,  -5,  0,  3,  -17,  -16,  -25,  -45,
-71,  -6,  11,  -1,  -9,  -20,  -16,  -44,
-26,  -37,  7,  16,  17,  1,  -13,  -19,
    ],

    chess.QUEEN:
    [
45,  43,  44,  59,  12,  29,  0,  -28,
54,  28,  57,  -16,  1,  -5,  -39,  -24,
57,  47,  56,  29,  8,  7,  -17,  -13,
1,  -2,  17,  -1,  -16,  -16,  -27,  -27,
-3,  3,  -4,  -2,  -10,  -9,  -26,  -9,
5,  14,  2,  -5,  -2,  -11,  2,  -14,
1,  -3,  15,  8,  2,  11,  -8,  -35,
-50,  -31,  -25,  -15,  10,  -9,  -18,  -1,
    ],

    chess.KING:
    [
13,  2,  -34,  -56,  -15,  16,  23,  -65,
-29,  -38,  -4,  -8,  -7,  -20,  -1,  29,
-22,  22,  6,  -20,  -16,  2,  24,  -9,
-36,  -14,  -25,  -30,  -27,  -12,  -20,  -17,
-51,  -33,  -44,  -46,  -39,  -27,  -1,  -49,
-27,  -15,  -30,  -44,  -46,  -22,  -14,  -14,
8,  9,  -16,  -43,  -64,  -8,  7,  1,
14,  24,  -28,  -44,  -54,  12,  36,  -15,
    ],

}

piece_square_tables_endgame = {
    chess.PAWN:
    [
0,  0,  0,  0,  0,  0,  0,  0,
187,  165,  132,  147,  134,  158,  173,  178,
84,  82,  53,  56,  67,  85,  100,  94,
17,  17,  4,  -2,  5,  13,  24,  32,
-1,  3,  -8,  -7,  -7,  -3,  9,  13,
-8,  -1,  -5,  0,  1,  -6,  7,  4,
-7,  2,  0,  13,  10,  8,  8,  13,
0,  0,  0,  0,  0,  0,  0,  0,
    ],

    chess.KNIGHT:
    [
-99,  -63,  -27,  -31,  -28,  -13,  -38,  -58,
-52,  -24,  -25,  -9,  -2,  -25,  -8,  -25,
-41,  -19,  -9,  -1,  9,  10,  -20,  -24,
-18,  8,  11,  22,  22,  22,  3,  -17,
-18,  4,  17,  16,  25,  16,  -6,  -18,
-22,  -20,  -3,  10,  15,  -1,  -3,  -23,
-44,  -23,  -20,  -2,  -5,  -10,  -20,  -42,
-64,  -50,  -18,  -22,  -15,  -23,  -51,  -29,
    ],

    chess.BISHOP:
    [
-24,  -17,  -9,  -7,  -8,  -11,  -21,  -14,
-14,  -4,  -13,  -3,  -12,  7,  -4,  -8,
4,  0,  6,  -2,  -1,  0,  -8,  2,
2,  3,  10,  14,  9,  12,  9,  -3,
-9,  -3,  10,  7,  19,  13,  3,  -6,
-15,  -7,  3,  13,  10,  8,  -3,  -12,
-27,  -15,  -9,  4,  -1,  -7,  -18,  -14,
-17,  -5,  -16,  -9,  -5,  -23,  -9,  -23,
    ],

    chess.ROOK:
    [
5,  8,  12,  12,  15,  18,  10,  13,
3,  8,  3,  -3,  11,  13,  13,  11,
-3,  -5,  -3,  4,  5,  7,  7,  7,
2,  -1,  1,  2,  1,  13,  3,  4,
-11,  -8,  -6,  -5,  4,  8,  5,  3,
-16,  -8,  -12,  -7,  -1,  -5,  0,  -4,
-3,  -11,  -9,  -9,  2,  0,  -6,  -6,
-20,  4,  -13,  -5,  -1,  3,  2,  -9,
    ],

    chess.QUEEN:
    [
20,  10,  19,  27,  27,  22,  22,  -9,
0,  30,  25,  58,  41,  32,  20,  -17,
9,  19,  35,  47,  49,  9,  6,  -20,
36,  57,  40,  57,  45,  24,  22,  3,
23,  39,  34,  31,  47,  19,  28,  -18,
5,  10,  17,  9,  6,  15,  -27,  -16,
-32,  -36,  -23,  -16,  -16,  -30,  -23,  -22,
-41,  -20,  -32,  -5,  -43,  -22,  -28,  -33,
    ],

    chess.KING:
    [
-17,  4,  15,  -11,  -18,  -18,  -35,  -74,
11,  23,  38,  17,  17,  14,  17,  -12,
13,  44,  45,  20,  15,  23,  17,  10,
3,  26,  33,  26,  27,  24,  22,  -8,
-11,  9,  23,  27,  24,  21,  -4,  -18,
-9,  7,  16,  23,  21,  11,  -3,  -19,
-17,  -5,  4,  14,  13,  4,  -11,  -27,
-43,  -24,  -14,  -28,  -11,  -21,  -34,  -53,
    ],

}

def evaluate_board(board):
    midgame = not is_endgame(board)

    if midgame:
        piece_values = piece_values_midgame
        piece_square_tables = piece_square_tables_midgame
    else:
        piece_values = piece_values_endgame
        piece_square_tables = piece_square_tables_endgame

    evaluation = 0

    for square in chess.SQUARES:
        piece = board.piece_at(square)
        if piece is not None:
            sign = 1 if piece.color == chess.WHITE else -1
            piece_type = piece.piece_type

            color = piece.color

            if color == chess.WHITE:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][63 - square]
            else:
                # Get the piece square value based on midgame or endgame
                square_value = piece_square_tables[piece_type][square]

            evaluation += sign * (piece_values[piece_type] + square_value)

    return evaluation


def is_endgame(board):
  # Check if there are no major pieces
  no_major_pieces = (
      sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0)
  if no_major_pieces:
    return True

  # Check for two rooks and no queen
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) <= 1):
    return True

  # Check for two queens or less, kings, and no other pieces except pawns
  if (sum(1 for _ in board.pieces(chess.QUEEN, chess.WHITE)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.WHITE)) == 0
      and sum(1 for _ in board.pieces(chess.QUEEN, chess.BLACK)) <= 1
      and sum(1 for _ in board.pieces(chess.KNIGHT, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.BISHOP, chess.BLACK)) == 0
      and sum(1 for _ in board.pieces(chess.ROOK, chess.BLACK)) == 0):
    return True

  # If none of the above conditions are met, return False
  return False

def quiescence_search(board, color, alpha, beta, ply):

    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0

    if board.is_checkmate():
            return -10000+ply
    
    stand_pat = color * evaluate_board(board)
    if stand_pat >= beta:
        return beta
    if alpha < stand_pat:
        alpha = stand_pat

    # Sort capture moves using MVV-LVA ordering
    capture_moves = [move for move in board.legal_moves if board.is_capture(move)]
    ordered_moves = sorted(capture_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        score = -quiescence_search(board, -color, -beta, -alpha, ply+1)
        board.pop()

        if score >= beta:
            return beta
        if score > alpha:
            alpha = score

    return alpha

def mvv_lva(board, move):

    # Get the piece at the destination square, or None if the square is empty
    to_piece = board.piece_at(move.to_square)

    # Get the piece at the source square, or None if the square is empty
    from_piece = board.piece_at(move.from_square)

    # Prioritize castling moves
    if board.is_castling(move):
        return 1000

    # Prioritize promotions
    if move.promotion is not None:
        promotion_value = piece_values_midgame[move.promotion] - piece_values_midgame[chess.PAWN]
        return promotion_value

    # Calculate MVV-LVA score for a move
    if to_piece is not None and from_piece is not None:
        return piece_values_midgame[to_piece.piece_type] - piece_values_midgame[from_piece.piece_type]
    else:
        # Return a low score for quiet moves
        return -1  # You can adjust this value based on your preferences



def negamax(board, depth, color, alpha, beta, ply, nodes):
    if board.can_claim_draw() or board.is_stalemate() or board.is_insufficient_material():
            return 0, nodes

    if board.is_checkmate():
            return -10000+ply, nodes
        
    if depth == 0 or board.is_game_over():
        return quiescence_search(board, color, alpha, beta, ply+1), nodes

    # Sort legal moves using MVV-LVA ordering
    ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)

    for move in ordered_moves:
        board.push(move)
        nodes += 1
        value, nodes = negamax(board, depth - 1, -color, -beta, -alpha, ply+1, nodes)
        value = -value
        board.pop()

        alpha = max(alpha, value)
        if alpha >= beta:
            break

    return alpha, nodes

transposition_table = {}

def best_move(board, start_time, max_time, depth):
    if board.turn == chess.WHITE:
        color = 1
    else: 
        color = -1

    alpha = float('-inf')
    beta = float('inf')
    ply = 0
    nodes = 0

    opening_book_path = 'book/komodo.bin'  # Use the .bin file for polyglot
    # Try moves from the opening book first
    with chess.polyglot.open_reader(opening_book_path) as reader:
        for entry in reader.find_all(board):
            move = entry.move
            if move in board.legal_moves:
                return move  # Return a move from the opening book

    best_mv = None

    for current_depth in range(1, depth + 1):
        elapsed_time = time.time() - start_time
        if elapsed_time >= max_time:
            return best_mv  # Exit the function immediately if max_time is reached
        ordered_moves = sorted(board.legal_moves, key=lambda move: mvv_lva(board, move), reverse=True)

        for move in ordered_moves:
            board.push(move)
            nodes += 1
            if board.is_checkmate():
                return move
            eval, nodes = negamax(board, current_depth - 1, -color, -beta, -alpha, ply+1, nodes)
            eval = -eval
            board.pop()

            if eval > alpha:
                alpha = eval
                best_mv = move

        print(f"info depth {current_depth} score cp {alpha} nps {int(nodes/max(0.01, elapsed_time))} time {int(elapsed_time*1000)} pv {best_mv.uci()}")

    return best_mv


def calculateMaxTime(remaining_time):
    return remaining_time / 60

DEFAULT_WTIME = 1000000
DEFAULT_BTIME = 1000000

def parse_parameters(line):
    parameters = line.split()[1:]
    wtime, btime = DEFAULT_WTIME, DEFAULT_BTIME

    for i in range(len(parameters)):
        if parameters[i] == "wtime" and i + 1 < len(parameters):
            wtime = float(parameters[i + 1])
        elif parameters[i] == "btime" and i + 1 < len(parameters):
            btime = float(parameters[i + 1])

    return wtime, btime

def play_chess():
    board = chess.Board()
    remaining_time = 1000000

    while True:
        line = input()
        if line == "uci":
            print("id name PyGo")
            print("id author Chess123easy")
            print("uciok")
        elif line == "isready":
            print("readyok")
        elif line.startswith("position startpos"):
            board = chess.Board()
            if "moves" in line:
                _, moves_part = line.split("moves")
                moves = moves_part.strip().split()
                for move in moves:
                    board.push_uci(move)
        elif line.startswith("position fen"):
            _, fen = line.split("fen", 1)
            board.set_fen(fen.strip())
        elif line.startswith("go"):
            wtime, btime = parse_parameters(line)
            remaining_time = wtime / 1000 if board.turn == chess.WHITE else btime / 1000

            start_time = time.time()
            max_time = calculateMaxTime(remaining_time)
            move = best_move(board, start_time, max_time, depth=3).uci()
            print(f"bestmove {move}")
        elif line == "quit":
            break

if __name__ == "__main__":
    play_chess()
# Out:
#  position fen 3r1r1k/1b2b2p/1q2pp2/n1n3p1/p5N1/P4PBP/BPPQ2P1/1R2R1K1 w - - 7 26
#  go
# info depth 1 score cp -174 nps 5500 time 0 pv d2f2
# info depth 2 score cp -174 nps 707 time 350 pv d2f2
# info depth 3 score cp -172 nps 1604 time 2372 pv d2b4
# bestmove d2b4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 417
#     414             break
#     416 if __name__ == "__main__":
# --> 417     play_chess()
#
# Cell In[38], line 388, in play_chess()
#     385 remaining_time = 1000000
#     387 while True:
# --> 388     line = input()
#     389     if line == "uci":
#     390         print("id name PyGo")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
